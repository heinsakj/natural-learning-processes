# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
import pandas as pd
import random

# %%
# your code here
n = 1600000
s = 20000
skip = sorted(random.sample(range(n), n-s))
tweets = pd.read_csv("training.1600000.processed.noemoticon.csv", skiprows = skip, encoding = "utf-8", encoding_errors = 'replace')

# %%
tweets.columns = ['target','id','date','flag','user','text']
tweets
# Out:
#        target          id                          date      flag  \
# 0           0  1467857378  Mon Apr 06 22:31:57 PDT 2009  NO_QUERY
# 1           0  1467875208  Mon Apr 06 22:36:39 PDT 2009  NO_QUERY
# 2           0  1467919765  Mon Apr 06 22:48:54 PDT 2009  NO_QUERY
# 3           0  1467946137  Mon Apr 06 22:56:25 PDT 2009  NO_QUERY
# 4           0  1467953738  Mon Apr 06 22:58:37 PDT 2009  NO_QUERY
# ...       ...         ...                           ...       ...
# 19994       4  2193475716  Tue Jun 16 08:30:34 PDT 2009  NO_QUERY
# 19995       4  2193476157  Tue Jun 16 08:30:36 PDT 2009  NO_QUERY
# 19996       4  2193476207  Tue Jun 16 08:30:36 PDT 2009  NO_QUERY
# 19997       4  2193526931  Tue Jun 16 08:34:42 PDT 2009  NO_QUERY
# 19998       4  2193554237  Tue Jun 16 08:36:55 PDT 2009  NO_QUERY
#
#                   user                                               text
# 0           Shabbybebe  Staying at a friends house...house sitting, ne...
# 1               realin  Damn i am so late at filling this appraisal fo...
# 2              aerlyne  Is stressing out because my blackberry keeps f...
# 3             kelilyma  Can't sleep again. Face is kinda swollen. Don'...
# 4             CaseLynn     @carlyw66 HAHA. I cried...  I guess he did....
# ...                ...                                                ...
# 19994   vincentdidier1                           @yourteube  bah de rien
# 19995  Kayleigh_Morris  @Elise_Olivia Haha all the nicknames ppl cal m...
# 19996    Adriana_Raven          @absolutspacegrl Doing all 3 dances now!
# 19997   Killer_Burrito  Okay so the plan is to go to hot topic and buy...
# 19998     krazikiddx09  Getting ready to have a picnic in the park w/ ...
#
# [19999 rows x 6 columns]

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# %run challenge-1.ipynb     #this is were my function was stored
clean_up(string)           #simply run the function
# Out:
# ['@', "ironhack's-", '#', 'q', 'websit', '776-i', 'http', ':', '//ironhack.com', '[', '(', '2018', ')', ']', "''", ')']
# ' ironhack s q website is '

# %%
# clean_up
tweets['text_processed']= tweets.apply(lambda row :clean_up(row['text_processed']), axis = 1)
tweets
# Out:
#        target          id                          date      flag  \
# 0           0  1467857378  Mon Apr 06 22:31:57 PDT 2009  NO_QUERY
# 1           0  1467875208  Mon Apr 06 22:36:39 PDT 2009  NO_QUERY
# 2           0  1467919765  Mon Apr 06 22:48:54 PDT 2009  NO_QUERY
# 3           0  1467946137  Mon Apr 06 22:56:25 PDT 2009  NO_QUERY
# 4           0  1467953738  Mon Apr 06 22:58:37 PDT 2009  NO_QUERY
# ...       ...         ...                           ...       ...
# 19994       4  2193475716  Tue Jun 16 08:30:34 PDT 2009  NO_QUERY
# 19995       4  2193476157  Tue Jun 16 08:30:36 PDT 2009  NO_QUERY
# 19996       4  2193476207  Tue Jun 16 08:30:36 PDT 2009  NO_QUERY
# 19997       4  2193526931  Tue Jun 16 08:34:42 PDT 2009  NO_QUERY
# 19998       4  2193554237  Tue Jun 16 08:36:55 PDT 2009  NO_QUERY
#
#                   user                                               text  \
# 0           Shabbybebe  Staying at a friends house...house sitting, ne...
# 1               realin  Damn i am so late at filling this appraisal fo...
# 2              aerlyne  Is stressing out because my blackberry keeps f...
# 3             kelilyma  Can't sleep again. Face is kinda swollen. Don'...
# 4             CaseLynn     @carlyw66 HAHA. I cried...  I guess he did....
# ...                ...                                                ...
# 19994   vincentdidier1                           @yourteube  bah de rien
# 19995  Kayleigh_Morris  @Elise_Olivia Haha all the nicknames ppl cal m...
# 19996    Adriana_Raven          @absolutspacegrl Doing all 3 dances now!
# 19997   Killer_Burrito  Okay so the plan is to go to hot topic and buy...
# 19998     krazikiddx09  Getting ready to have a picnic in the park w/ ...
#
#                                           text_processed
# 0      staying at a friends house house sitting neigh...
# 1      damn i am so late at filling this appraisal fo...
# 2      is stressing out because my blackberry keeps f...
# 3      can t sleep again face is kinda swollen don t ...
# 4                    carlyw haha i cried i guess he did
# ...                                                  ...
# 19994                             yourteube bah de rien
# 19995   elise olivia haha all the nicknames ppl cal m...
# 19996              absolutspacegrl doing all dances now
# 19997  okay so the plan is to go to hot topic and buy...
# 19998  getting ready to have a picnic in the park w m...
#
# [19999 rows x 7 columns]

# %%
# tokenize
tweets['text_processed']= tweets.apply(lambda row :tokenize(row['text_processed']), axis = 1)

# %%
# Stemming and lemmatize
tweets['text_processed']= tweets.apply(lambda row :stem_and_lemmatize(row['text_processed']), axis = 1)
# Out:
# ['stay', 'at', 'a', 'friend', 'hous', 'hous', 'sit', 'neighbor', 'are', 'so', 'loud', 'have', 'a', 'parti']
# ['damn', 'i', 'am', 'so', 'late', 'at', 'fill', 'thi', 'apprais', 'form', 'peopl', 'have', 'almost', 'sent', 'it', 'i', 'wa', 'so', 'occupi', 'in', 'work']
# ['is', 'stress', 'out', 'becaus', 'my', 'blackberri', 'keep', 'flash', 'a', 'red', 'alert', 'statu', 'for', 'no', 'reason', 'it', 'fake', 'me', 'out', 'and', 'i', 'hate', 'it']
# ['can', 't', 'sleep', 'again', 'face', 'is', 'kinda', 'swollen', 'don', 't', 'let', 'me', 'be', 'allerg', 'to', 'the', 'thing', 'that', 'll', 'get', 'me', 'to', 'thursday', 'school', 'tomorrow', 'doubt']
# ['carlyw', 'haha', 'i', 'cri', 'i', 'guess', 'he', 'did']
# ['monasmith', 'sadli', 'ye', 'i', 'think', 'i', 'need', 'council', 'now']
# ['off', 'to', 'london', 'for', 'the', 'day', 'on', 'thursday', 'it', 's', 'gon', 'na', 'be', 'rain', 'oh', 'fab', 'won', 't', 'see', 'much', 'on', 'the', 'london', 'eye', 'still', 'robbi', 'won', 't', 'care', 'bless', 'him']
# ['veri', 'tire', 'thi', 'morn', 'no', 'idea', 'whi', 'great', 'start', 'to', 'the', 'day']
# ['cmykevin', 'ooh', 'nice', 'but', 'william', 'sonoma', 'alreadi', 'got', 'to', 'me']
# ['someon', 'pleas', 'take', 'gossip', 'girl', 'away', 'from', 'me', 'i', 'm', 'addict']
# ['up', 'earli']
# ['train', 'ram', 'fellow', 'commut', 'vile', 'special', 'deris', 'reserv', 'for', 'the', 'man', 'who', 'appear', 'out', 'of', 'nowher', 'to', 'claim', 'hi', 'seat', 'luggag', 'rack']
# ['junebugg', 'i', 'had', 'to', 'super', 'glue', 'my', 'shoe', 'lol']
# ['ugh', 'just', 'read', 'on', 'cnn', 'that', 'they', 'found', 'the', 'cantu', 'girl', 's', 'bodi', 'in', 'a', 'pond', 'near', 'their', 'home', 'how', 'terribl', 'for', 'her', 'famili']
# ['texasvegetarian', 'oh', 'god', 'ow', 'that', 'must', 'have', 'hurt', 'like', 'a', 'bitch']
# ['meganh', 'same', 'it', 'ha', 'been', 'drizzl', 'all', 'day', 'if', 'u', 'are', 'go', 'to', 'rain', 'might', 'as', 'well', 'pour']
# ['darylsw', 'kid', 'are', 'on', 'holiday']
# ['kal', 'penn', 'omg', 'i', 'am', 'so', 'mad', 'you', 'were', 'my', 'favorit', 'charact', 'i', 'll', 'miss', 'you']
# ['martiy', 'ouchi', 'have', 'a', 'good', 'day', 'and', 'goodnight', 'supertim']
# ['somewher', 'in', 'the', 'world', 'right', 'now', 'the', 'sun', 'is', 'shine', 'and', 'peopl', 'are', 'busi', 'but', 'not', 'here']
# ['didnt', 'hear', 'from', 'my', 'hunn', 'today']
# ['seanport', 'thank', 'uuu', 'i', 'know', 'i', 'heard', 'your', 'in', 'dalla']
# ['the', 'one', 'day', 'i', 'realli', 'need', 'to', 'go', 'into', 'school', 'and', 'i', 'm', 'not', 'well']
# ['stompthewalru', 'haha', 'well', 'i', 'have', 'live', 'in', 'texa', 'the', 'past', 'year', 'i', 'think', 'that', 'explain', 'itself', 'lol', 'si', 'habla', 'espaool']
# ['shut', 'off', 'twitter']
# ['can', 't', 'sleep', 'and', 'wonder', 'whi', 'my', 'follow', 'keep', 'go', 'down', 'guess', 'i', 'got', 'ta', 'tri', 'and', 'be', 'more', 'interest', 'haha']
# ['want', 'a', 'polaroid', 'camera']
# ['need', 'hug']
# ['gnah', 'inner', 'tube', 'explod', 'got', 'ta', 'get', 'a', 'taxi', 'to', 'work', 'or', 'be', 'late']
# ['ugh', 'whi', 'did', 'my', 'mum', 'wake', 'me', 'up', 'so', 'earli', 'geesh', 'i', 'need', 'sleep', 'and', 'princessnadi', 'there', 'is', 'noth', 'awww']
# ['wish', 'restaur', 'citi', 'or', 'pet', 'societi', 'could', 'be', 'port', 'to', 'the', 'iphon', 'itouch']
# ['sooo', 'not', 'motiv', 'to', 'do', 'work']
# ['lucygooesi', 'haha', 'nice', 'barbi', 'backgroud', 'he', 'still', 'hasnt', 'repli', 'lol']
# ['as', 'usual', 'cook', 'what', 'i', 'hate']
# ['zoeaime', 'i', 'm', 'tri', 'to', 'research', 'some', 'dude', 'for', 'my', 'english', 'assign', 'that', 'is', 'due', 'tomorrow', 'and', 'my', 'internet', 'keep', 'freez', 'and', 'won', 't', 'load']
# ['big', 'blue', 'wolf', 'not', 'yet', 'no', 'doubt', 'i', 'll', 'get', 'a', 'chanc', 'to', 'until', 'tonight', 'work', 's', 'mental', 'thank', 'to', 'bt', 'cut', 'off', 'custom', 'today']
# ['no', 'that', 's', 'not', 'him', 'in', 'the', 'pictur', 'i', 'don', 't', 'have', 'ani', 'pic', 'yet']
# ['iamnipp', 'last', 'week', 'they', 've', 'got', 'the', 'bike', 'minu', 'a', 'saddl']
# ['bleh', 'i', 'strongli', 'dislik', 'work', 'at', 'am', 'everyday']
# ['found', 'a', 'nice', 'lake', 'side', 'park', 'with', 'a', 'small', 'beach', 'but', 'no', 'grill', 'oh', 'well', 'i', 'll', 'have', 'to', 'keep', 'look', 'anoth', 'time']
# ['thi', 'is', 'way', 'to', 'earli', 'to', 'go', 'to', 'work']
# ['have', 'a', 'ouchi', 'head', 'which', 'is', 'make', 'me', 'feel', 'sicki']
# ['cant', 'eat', 'drink', 'or', 'breath', 'properli', 'thank', 'to', 'the', 'bad', 'throat', 'infect']
# ['absolutelybatti', 'hug', 'back', 'thank', 'hon', 'i', 'can', 't', 'believ', 'he', 's', 'gone']
# ['urghhhhhh', 'tire', 'i', 'need', 'a', 'proper', 'lie', 'in']
# ['wish', 'i', 'wa', 'go', 'to', 'melbourn', 'thi', 'wkend', 'for', 'harlot', 'hous', 'at', 'tramp']
# ['marshmallowpi', 'luckili', 'not', 'lot', 'of', 'devast', 'there', 'veri', 'bad', 'situat']
# ['too', 'mani', 'updat', 'on', 'twitter', 'not', 'abl', 'to', 'follow', 'everyth']
# ['magicbartend', 'heya', 'aww', 'i', 'miss', 'ps', 'i', 'didnt', 'see', 'your', 'tweet', 'until', 'now']
# ['bonjourv', 'and', 'it', 'curiou', 'how', 'watch', 'the', 'news', 'can', 'bring', 'you', 'down']
# ['the', 'batteri', 'for', 'the', 'mous', 'broke', 'i', 'hate', 'use', 'the', 'laptop', 'touch', 'paddd']
# ['doesn', 't', 'understand', 'ohio', 'weather', 'it', 's', 'april', 'i', 'have', 'to', 'run', 'a', 'track', 'meet', 'in', 'short', 'and', 'a', 'tank', 'top', 'tonight', 'thi', 'is', 'gon', 'na', 'be', 'great']
# ['asheshwor', 'how', 'i', 'donot', 'understand']
# ['yay', 'back', 'home', 'earli', 'but', 'the', 'sod', 'will', 'no', 'doubt', 'make', 'me', 'work', 'from', 'home']
# ['wait', 'to', 'go', 'back', 'to', 'my', 'cold', 'lone', 'student', 'room', 'booo']
# ['miafreedman', 'i', 'm', 'love', 'harem', 'pant', 'at', 'the', 'moment', 'serious', 'but', 'not', 'the', 'one', 'with', 'a', 'crutch', 'to', 'the', 'knee', 'ewwww']
# ['friend', 'request', 'are', 'everywher', 'inhal', 'exhal']
# ['airbush', 'thank', 'for', 'the', 'guru', 'link', 'but', 'they', 'just', 'take', 'me', 'to', 'the', 'sign', 'in', 'page']
# ['miss', 'u', 'babi', 'r', 'u', 'awak', 'time', 'to', 'poke', 'ur', 'patient', 'alreadi']
# ['have', 'a', 'hard', 'time', 'concentr', 'my', 'cat', 'some', 'how', 'got', 'out', 'amp', 'ha', 'been', 'miss', 'for', 'a', 'day', 'he', 'is', 'liter', 'a', 'scaredi', 'cat', 'plu', 'it', 's', 'so', 'cold']
# ['jcg', 'i', 'hope', 'so', 'obvious', 'usag', 'is', 'a', 'massiv', 'factor', 'but', 'i', 'current', 'get', 'about', 'hour', 'out', 'of', 'my', 'n']
# ['just', 'when', 'i', 'think', 'hous', 'is', 'get', 'better', 'it', 'goe', 'and', 'pull', 'that', 'shit', 'what', 'the', 'hell', 'thi', 'show', 'ha', 'gotten', 'so', 'bad']
# ['there', 'is', 'a', 'green', 'hair', 'on', 'my', 'screen', 'and', 'i', 'cba', 'to', 'move', 'it']
# ['dirtya', 'lolll', 'nooo', 'then', 'i', 'm', 'back', 'to', 'my', 'protein', 'diet', 'mayb', 'on', 'a', 'cheat', 'day']
# ['falalala', 'la', 'it', 's', 'way', 'too', 'earli', 'to', 'be', 'tweet', 'but', 'my', 'stomach', 'feel', 'gnarli']
# ['say', 'pau', 'wag', 'ka', 'na', 'sad', 'pleas']
# ['could', 'it', 'be', 'bronchiti', 'or', 'is', 'it', 'just', 'allergi', 'ugh', 'i', 'feel', 'so', 'sick']
# ['alannahscott', 'that', 'long', 'thing', 'are', 'never', 'simpl', 'i', 'want', 'to', 'pierc', 'my', 'tongu', 'over', 'thi', 'holiday', 'but', 'couldnt', 'becaus', 'of', 'the', 'heal', 'time']
# ['still', 'at', 'airport', 'wait', 'been', 'on', 'ground', 'for', 'min']
# ['what', 'happen', 'to', 'april', 'thi', 'look', 'more', 'like', 'decemb']
# ['is', 'sick', 'to', 'bad', 'it', 'such', 'a', 'nice', 'weather', 'outsid', 'darn', 'it', 'oh', 'just', 'watch', 'hero', 'yay', 'parkmann', 'met', 'hi', 'son', 'soo', 'ador']
# ['emot', 'not', 'feel', 'good']
# ['offici', 'work', 'too', 'much', 'late', 'not', 'enough', 'time', 'to', 'play', 'with', 'my', 'lover', 'and', 'neither', 'of', 'us', 'is', 'pleas']
# ['miemofac', 'eeeeew', 'get', 'coffe', 'beforehand']
# ['is', 'pretti', 'sure', 'someon', 'is', 'eat', 'in', 'the', 'bathroom', 'stall', 'that', 's', 'realli', 'high', 'school', 'of', 'them', 'and', 'kind', 'of', 'sad']
# ['tactic', 'here', 'too']
# ['given', 'up', 'on', 'pdf', 'pars']
# ['school', 'till', 'today', 'boooo']
# ['argh', 'problem', 'with', 'keyr']
# ['mad', 'is', 'over', 'back', 'to', 'work']
# ['thi', 'is', 'where', 'i', 'will', 'be', 'park', 'for', 'the', 'next', 'three', 'day', 'no', 'window']
# ['ha', 'no', 'internet', 'access', 'and', 'need', 'an', 'iphon', 'clearli', 'to', 'keep', 'up', 'with', 'twitter', 'life', 'without', 'twitter', 'is', 'not', 'the', 'same']
# ['onlin', 'bankovnictv', 'kb', 'je', 'offlin', 'zrovna', 'kdi', 'je', 'to', 'nejv', 'c', 'pot', 'eba', 'lak', 'm', 'tref', 'grrr']
# ['i', 'dreamt', 'that', 'i', 'wa', 'fail', 'one', 'of', 'my', 'class', 'it', 'wa', 'not', 'fun']
# ['pleas', 'to', 'follow', 'lionelatdel', 'richardatdel', 'per', 'armano', 'i', 'have', 'a', 'about', 'my', 'yr', 'old', 'dell', 'inspiron', 'that', 's', 'now', 'die']
# ['treobenni', 'there', 'should', 'be', 'a', 'go', 'to', 'top', 'option', 'but', 'not', 'one', 'that', 'i', 'know', 'of']
# ['sandyguerrier', 'i', 'admit', 'it', 'it', 'wa', 'all', 'my', 'fault', 'i', 'accident', 'pull', 'the', 'power', 'cord', 'to', 'twitter', 'think', 'it', 'wa', 'for', 'my', 'laptop']
# ['how', 'far', 'away', 'will', 'tier', 'be']
# ['nice', 'morn', 'for', 'our', 'walk', 'a', 'breez', 'out', 'of', 'the', 'n', 'clear', 'sky', 'still', 'not', 'done', 'with', 'the', 'tax']
# ['watch', 'snow', 'fall', 'in', 'winchest', 'in', 'april']
# ['kim', 'that', 'is', 'a', 'bad', 'sunburn', 'i', 'have', 'had', 'that', 'kind', 'of', 'sunburn', 'need', 'to', 'put', 'a', 'lot', 'of', 'lotion', 'look', 'pain']
# ['might', 'get', 'into', 'a', 'fight', 'tomorrow']
# ['latinluvli', 'awww', 'i', 'love', 'my', 'babi', 'can', 't', 'think', 'about', 'be', 'without', 'her', 'i', 'even', 'hate', 'leav', 'her', 'in', 'the', 'morn', 'to', 'go', 'to', 'work']
# ['i', 'm', 'so', 'upset', 'with', 'thi', 'phone', 'i', 'hope', 'it', 'isn', 't', 'broken', 'for', 'good', 'stupid', 't', 'mobil']
# ['get', 'the', 'hang', 'of', 'thi', 'but', 'none', 'of', 'my', 'friend', 'r', 'even', 'on', 'here']
# ['iamthecommodor', 'i', 'couldnt', 'make', 'it', 'gt', 'lt', 'i', 'went', 'to', 'the', 'movi', 'sooo', 'sorri']
# ['acenadren', 'haha', 'you', 'wouldn', 't', 'becaus', 'you', 're', 'wear', 'them']
# ['is', 'say', 'goodby', 'to', 'her', 'momma', 'for', 'month']
# ['fuck', 'i', 'feel', 'like', 'i', 'could', 'cri', 'right', 'now']
# ['american', 'apparel', 'kid']
# ['cdavi', 'the', 'milwauke', 'iron', 'first', 'year', 'expans', 'team', 'from', 'what', 'i', 'hear', 'they', 'lost', 'i', 'didn', 't', 'realiz', 'it', 'wa', 'still', 'around', 'either']
# ['eerland', 'someth', 'in', 'the', 'air', 'edi', 'woke', 'up', 'a', 'bit', 'ago', 'wimper', 'in', 'her', 'sleep', 'i', 'had', 'to', 'go', 'sooth', 'her', 'while', 'she', 'quietli', 'cri', 'it', 'out']
# ['wait', 'for', 'him', 'to', 'go', 'onlin', 'lucki', 'me', 'i', 'wa', 'eat', 'when', 'he', 'ime', 'me', 'and', 'now', 'he', 's', 'offlin', 'dayuuum']
# ['my', 'babi', 'boo', 'love', 'of', 'my', 'life', 'best', 'friend', 'evar', 'is', 'final', 'tweet', 'or', 'twat', 'victoriazombi']
# ['i', 'don', 't', 'understand', 'whi', 'some', 'of', 'the', 'best', 'peopl', 'in', 'the', 'world', 'are', 'thrown', 'to', 'the', 'ground', 'by', 'evil', 'i', 'wish', 'life', 'wa', 'fair', 'to', 'all', 'who', 'are', 'good']
# ['im', 'so', 'tire', 'of', 'thi', 'i', 'just', 'want', 'you', 'back', 'home', 'where', 'you', 'belong', 'thing', 'arent', 'meant', 'to', 'end', 'thi', 'way']
# ['mannnn', 'i', 'gern', 'out', 'man', 'lol', 'i', 'cnt', 'take', 'be', 'gang', 'up', 'on']
# ['i', 'can', 't', 'believ', 'i', 'am', 'work', 'on', 'such', 'a', 'beauti', 'day']
# ['up', 'at', 'am', 'on', 'a', 'saturday', 'boo', 'photo', 'shoot', 'be', 'back', 'probabl', 'later', 'tonight', 'xo']
# ['my', 'daughter', 'isnt', 'start', 'her', 'day', 'off', 'right', 'tri', 'prom', 'dress', 'on', 'amp', 'it', 'doesnt', 'fit', 'gain', 'a', 'littl', 'weight']
# ['xkeijukainenx', 'wtf', 'i', 'would', 'disown', 'my', 'famili', 'if', 'they', 'did', 'that', 'that', 's', 'some', 'bs', 'and', 'i', 'feel', 'bad', 'for', 'your', 'mommi']
# ['is', 'look', 'out', 'in', 'the', 'garden', 'wonder', 'if', 'the', 'chicken', 'will', 'be', 'impress', 'if', 'i', 'destroy', 'their', 'garden', 'like', 'theyr', 'do', 'to', 'mine']
# ['itvhellskitchen', 'is', 'that', 'preview', 'for', 'uk', 'visitor', 'onli', 'there', 'are', 'roi', 'hell', 's', 'kitchen', 'fan', 'too']
# ['johnrobinson', 'that', 'realli', 'too', 'bad']
# ['guess', 'who', 's', 'bizzzack', 'btw', 'move', 'piec', 'of', 'luggag', 'with', 'hand', 'is', 'haaaaard']
# ['build', 'email', 'templat', 'for', 'outlook', 'is', 'a', 'nightmar']
# ['busi', 'commun', 'i', 'in', 'sorunlu', 'bi', 'yerd', 'yemek', 'yemesi', 'gerek']
# ['had', 'a', 'fun', 'day', 'with', 'highschool', 'buddi', 'but', 'came', 'home', 'to', 'find', 'one', 'goldfish', 'had', 'die', 'and', 'i', 'don', 't', 'know', 'what', 'it', 'die', 'of']
# ['not', 'go', 'to', 'the', 'basebal', 'game', 'with', 'dakota', 'today', 'but', 'im', 'watch', 'brandon', 'at']
# ['bah', 'delay', 'anoth', 'half', 'hour', 'weather', 'condit', 'in', 'sfo']
# ['timmetri', 'noe', 'it', 's', 'saturday', 'it', 'll', 'be', 'slow', 'all', 'day']
# ['do', 'my', 'best', 'to', 'figur', 'out', 'how', 'to', 'tweet', 'tri', 'to', 'upload', 'my', 'photo']
# ['happymonkeysho', 'ditto', 'i', 'wa', 'not', 'impress', 'with', 'last', 'wednesday', 's', 'onlin', 'order', 'issu']
# ['ginapetri', 'first', 'game', 'is', 'at', 'noon', 'it', 'rain']
# ['mothersload', 'it', 's', 'go', 'to', 'be', 'more', 'of', 'a', 'hous', 'clean', 'day', 'sinc', 'it', 's', 'start', 'to', 'spit', 'outsid', 'a', 'littl']
# ['homework']
# ['i', 'm', 'watch', 'tv', 'that', 'must', 'sound', 'like', 'a', 'lot', 'of', 'fun', 'boohoo', 'it', 'rain']
# ['wish', 'i', 'had', 'my', 'carmera']
# ['dogqual', 'that', 's', 'just', 'not', 'right', 'sorri']
# ['my', 'stomach', 'hurt', 'busi', 'day', 'ahead', 'of', 'me', 'go', 'on', 'hour', 'of', 'sleep']
# ['is', 'clean']
# ['inthisc', 'i', 'hear', 'ya', 'i', 'm', 'at', 'about', 'it', 'wa', 'due', 'in', 'week', 'ago']
# ['katyperri', 'go', 'to', 'grad', 'night', 'on', 'the', 'hope', 'we', 'see', 'u', 'we', 'are', 'from', 'ecuador', 'and', 'love', 'you', 'want', 'to', 'go', 'to', 'ft', 'lauderdal', 'the', 'sold', 'out']
# ['is', 'sooo', 'hungri', 'to', 'bad', 'the', 'dc', 'is', 'close']
# ['soooo', 'tire', 'after', 'last', 'nite', 'mad', 'tri', 'to', 'find', 'the', 'motiv', 'from', 'somewher', 'to', 'do', 'some', 'teelin', 'shorthand', 'practic', 'not', 'fun']
# ['tomacintosh', 'yeah', 'tell', 'me', 'about', 'it']
# ['i', 'm', 'not', 'find', 'it', 'interest', 'log', 'in', 'to', 'see', 'onli', 'statu', 'updat', 'bore']
# ['amazingphoeb', 'i', 'do', 'want', 'to', 'care', 'you', 'just', 'make', 'it', 'so', 'extrem', 'difficult', 'sometim', 'i', 'do', 'want', 'to', 'love', 'you', 'ye', 'night', 'xxxxx']
# ['themandymoor', 'i', 'want', 'to', 'watch', 'dedic', 'but', 'can', 't', 'find', 'it', 'in', 'store', 'great', 'movi', 'by', 'the', 'way']
# ['krodbro', 'well', 'i', 'll', 'have', 'to', 'come', 'out', 'to', 'chicago', 'at', 'some', 'point', 'thi', 'summer', 'then']
# ['plaid', 'happi', 'i', 'wish', 'i', 'wa', 'good', 'at', 'someth']
# ['guytustin', 'ugh', 'i', 'know', 'i', 'live', 'right', 'off', 'of', 'conroy', 'past', 'kirkman', 'and', 'that', 'light', 'easili', 'make', 'a', 'minut', 'trip', 'a', 'minut', 'one']
# ['rosedairi', 'i', 'have', 'class', 'until', 'six']
# ['thi', 'whole', 'tweet', 'under', 'my', 'real', 'name', 'thing', 'is', 'sorta', 'scari', 'so', 'much', 'need', 'for', 'self', 'censorship']
# ['playoff', 'time', 'kinda', 'weird', 'not', 'watch', 'the', 'sun', 'let', 's', 'go', 'cav', 'bron', 'bron', 'need', 'a', 'ring']
# ['mileycyru', 'safe', 'jpurney', 'co', 'imm', 'one', 'off', 'uur', 'fan', 'lol', 'thaa', 'mii', 'amp', 'amp', 'uue', 'never', 'repli', 'to', 'anythiiin', 'i', 'send', 'uue', 'not', 'fair', 'lol']
# ['oceanuptwitt', 'it', 's', 'onli', 'for', 'the', 'us', 'countri', 'i', 'guess']
# ['craigthom', 'i', 'll', 'be', 'there', 'soon', 'enough']
# ['the', 'indian', 'score', 'run', 'in', 'inning']
# ['i', 'want', 'to', 'take', 'a', 'trip', 'across', 'the', 'countri', 'with', 'my', 'friend', 'but', 'my', 'parent', 'want', 'me', 'to', 'find', 'a', 'job', 'first']
# ['david', 'henri', 'i', 'wish', 'i', 'could', 'meet', 'you', 'but', 'you', 're', 'alll', 'the', 'way', 'out', 'in', 'lo', 'angel', 'lol']
# ['seem', 'like', 'someth', 'is', 'alway', 'break', 'around', 'here', 'last', 'week', 'car', 'problem', 'thi', 'week', 'a', 'broken', 'plumb', 'pipe', 'so', 'current', 'no', 'water']
# ['i', 'feel', 'so', 'bad', 'now', 'it', 'suck', 'when', 'peopl', 'are', 'so', 'nice', 'to', 'you']
# ['blackpearl', 'thank', 'me', 'too', 'but', 'by', 'the', 'look', 'of', 'the', 'radar', 'we', 'are', 'go', 'to', 'get', 'pound', 'until', 'later', 'tonight']
# ['off', 'to', 'work']
# ['jglynn', 'im', 'bare', 'hang', 'on', 'almost', 'over', 'then', 'we', 'can', 'playyyyy']
# ['msgjone', 'i', 'love', 'csi', 'vega', 'but', 'it', 's', 'not', 'the', 'same', 'without', 'grissom', 'amp', 'warrick']
# ['saturday', 'night', 'em', 'casa', 'rs']
# ['whi', 'is', 'it', 'sooo', 'hot']
# ['fistynut', 'hope', 'it', 'doesn', 't', 'come', 'near', 'our', 'bloodi', 'car', 'is', 'cake', 'in', 'birdshit', 'again']
# ['lost', 'my', 'creativ', 'bug', 'start', 'a', 'great', 'essay', 'and', 'a', 'letter', 'to', 'the', 'bf', 'while', 'sip', 'on', 'wine']
# ['did', 'a', 'reboot', 'and', 'i', 'still', 'can', 't', 'get', 'adob', 'air', 'to', 'uninstal']
# ['joeaa', 'omg', 'ik', 'the', 'yanke', 'are', 'get', 'kill', 'by', 'cleveland', 'haha', 'oh', 'boy', 'tip', 'repli', 'with', 'whoi', 'joeaa', 'for', 'more', 'info']
# ['lost', 'follow', 'wa', 'it', 'someth', 'i', 'said', 'oh', 'well', 'i', 'could', 'have', 'told', 'you', 'i', 'wa', 'bore', 'd']
# ['miss', 'shan', 'hmmm', 'that', 's', 'a', 'good', 'question', 'i', 'll', 'tweet', 'you', 'when', 'i', 'do', 'i', 'wish', 'i', 'could', 'go', 'on', 'now', 'x']
# ['stupid', 'caffin', 'headach', 'i', 'hate', 'the', 'addict', 'grrrr']
# ['db', 'birthday', 'it', 'so', 'hot']
# ['i', 'm', 'not', 'a', 'fan', 'of', 'cold', 'morn']
# ['is', 'scare', 'at', 'how', 'much', 'jame', 'and', 'me', 'are', 'alik']
# ['jimmymarsh', 'i', 'wish', 'i', 'wa', 'go']
# ['arseblog', 'couldnt', 'agre', 'more', 'so', 'upset', 'gibb', 'and', 'theo', 'the', 'onli', 'real', 'posit', 'and', 'even', 'then', 'that', 'look', 'hard', 'for', 'that', 'silver', 'line']
# ['marcushazzard', 'ugh', 'homework', 'ive', 'got', 'no', 'money', 'i', 'wish', 'i', 'could', 'go', 'danc', 'tonight', 'what', 'about', 'you']
# ['kristosbabi', 'lol', 'mee', 'too', 'although', 'it', 's', 'more', 'to', 'do', 'with', 'how', 'skint', 'i', 'am', 'we', 'shall', 'all', 'need', 'to', 'get', 'a', 'wee', 'lunch', 'sometim', 'soon', 'though']
# ['still', 'at', 'offic', 'work', 'on', 'coursework']
# ['i', 'wonder', 'how', 'do', 'i', 'start', 'freelanc', 'again', 'i', 'lost', 'all', 'my', 'contact']
# ['i', 'just', 'saw', 'an', 'ice', 'cream', 'truck', 'but', 'i', 'had', 'no', 'cash']
# ['can', 'we', 'have', 'someth', 'like', 'hotspot', 'shield', 'for', 'ubuntu', 'i', 'am', 'desper', 'for', 'youtub', 'here']
# ['ashleyrwatt', 'fight', 'and', 'i', 'have', 'a', 'feel', 'the', 'vast', 'major', 'are', 'go', 'to', 'becom', 'custom', 'lt']
# ['it', 's', 'hot']
# ['just', 'lost', 'the', 'game']
# ['play', 'with', 'je', 'deinterlac', 'to', 'slow', 'down', 'some', 'video', 'wish', 'i', 'could', 'shoot', 'hd', 'clip']
# ['i', 'am', 'miss', 'the', 'game', 'i', 've', 'miss', 'all', 'the', 'game', 'today', 'and', 'thi', 'is', 'the', 'last', 'one', 'today', 'and', 'i', 'm', 'about', 'to', 'miss', 'thi', 'one']
# ['vvperri', 'you', 'don', 't', 'miss', 'me', 'i', 'm', 'sad']
# ['is', 'walkin', 'home', 'from', 'the', 'footbal', 'co', 'he', 'could', 'not', 'befor', 'a', 'ticket']
# ['what', 'is', 'everyon', 'do', 'bore']
# ['eat', 'layer', 'of', 'choco', 'heaven', 'missin', 'the', 'ic', 'middl', 'america', 'team']
# ['bill', 'o', 'riley', 'put', 'the', 'crazi', 'in', 'my', 'crazi', 'juic', 'that', 'i', 'drink', 'not', 'hi', 'juic', 'ahh', 'nevermind']
# ['i', 'had', 'to', 'keep', 'it', 'up', 'for', 'second', 'i', 'onli', 'did']
# ['nope', 'you', 'alreadi', 'hurt', 'my', 'feel', 'no', 'apolog', 'j', 'k', 'that', 'stink', 'how', 'long', 'til', 'you', 'come', 'back']
# ['be', 'bore', 'as', 'usual', 'amp', 'amp', 'lost', 'my', 'voic']
# ['emmafoxforc', 'holi', 'crap', 'aw', 'amp', 'superscari', 'wish', 'i', 'came', 'out', 'meet', 'yall', 'stella', 'thur', 'mayb', 'i', 'coulda', 'help', 'just', 'glad', 'nobodi', 'got', 'hurt']
# ['think', 'a', 'final', 'score', 'of', 'is', 'so', 'disappoint']
# ['drangeliqu', 'no', 'kid', 'i', 'think', 'we', 'may', 'final', 'have', 'it', 'go', 'but', 'it', 'is', 'past', 'my', 'bedtim', 'thi', 'is', 'now', 'gon', 'na', 'take', 'all', 'night', 'sato']
# ['im', 'veri', 'tire', 'head', 'to', 'the', 'bed', 'now', 'alon']
# ['elizabethjoan', 'she', 'look', 'cute', 'when', 'shawn', 'first', 'met', 'her', 'at', 'the', 'coffe', 'shop', 'but', 'now', 'i', 'm', 'on', 'the', 'wed', 'ep', 'and', 'she', 's', 'just', 'so', 'drab']
# ['there', 'need', 'to', 'be', 'better', 'hotter', 'lingeri', 'for', 'girl', 'with', 'big', 'boob', 'fuck', 'if', 'i', 'knew', 'how', 'i', 'd', 'just', 'make', 'them', 'myself']
# ['suewat', 'map', 'won', 't', 'let', 'me', 'put', 'myself', 'on', 'it', 'la', 'loch', 'must', 'be', 'too', 'small']
# ['just', 'got', 'back', 'from', 'nyc', 'the', 'citi', 'wa', 'fantast', 'buy', 'the', 'yanke', 'got', 'slaughter']
# ['my', 'pierc', 'is', 'bleed', 'yet', 'again']
# ['belli', 'asplod', 'had', 'fun', 'w', 'patti', 'nite', 'new', 'verdict', 'in', 'my', 'life', 'quot', 'i', 'm', 'not', 'gon', 'na', 'sit', 'around', 'amp', 'wait', 'u', 'anymor', 'quot', 'attach', 'fade']
# ['musicale', 'i', 'm', 'a', 'loser', 'lol']
# ['po', 'po', 'block', 'off', 'my', 'hood', 'and', 'i', 'cant', 'get', 'to', 'mai', 'hous', 'i', 'hope', 'marin', 'is', 'ok']
# ['dasschu', 'i', 'm', 'veri', 'sorri', 'for', 'your', 'loss', 'lose', 'pet', 'is', 'realli', 'hard']
# ['tinytwitt', 'suck']
# ['i', 'wish', 'i', 'got', 'messag']
# ['ahhh', 'all', 'of', 'fftl', 's', 'merch', 'on', 'their', 'site', 'is', 'soooo', 'cheap', 'i', 'want', 'it', 'but', 'im', 'poor']
# ['sugarfairi', 'oh', 'no', 'sorri', 'hon']
# ['go', 'back', 'home', 'such', 'a', 'xsue', 'of', 'time']
# ['i', 'wan', 'na', 'go', 'home']
# ['i', 'wish', 'i', 'had', 'verizon', 'i', 'want', 'that', 'new', 'blackberri', 'click', 'phone']
# ['yogini', 'i', 'bought', 'a', 'puppi', 'mill', 'peopl', 'and', 'didn', 't', 'know', 'it', 'year', 'ago', 'and', 'he', 'as', 'so', 'sick', 'and', 'die', 'at', 'yr', 'old']
# ['empressericka', 'oh', 'well', 'i', 'tri']
# ['wrote', 'the', 'fuck', 'greatest', 'song', 'in', 'my', 'sleep', 'last', 'night', 'now', 'can', 't', 'rememb', 'it', 'school', 'goe', 'back', 'tomorrow']
# ['cheer', 'up', 'wake', 'up', 'coffe', 'kick', 'in', 'whi', 'is', 'it', 'that', 'i', 'alway', 'get', 'hungri', 'and', 'want', 'to', 'go', 'to', 'mcd', 's', 'at', 'am', 'on', 'sat', 'when', 'it', 's', 'swamp']
# ['about', 'to', 'go', 'to', 'sleep', 'go', 'see', 'the', 'doc', 'tomorrow', 'ahhh', 'i', 'wan', 'na', 'be', 'done', 'thi', 'weekend', 'is', 'weird']
# ['back', 'to', 'the', 'work', 'again', 'thi', 'morn', 'fun', 'time']
# ['melissamunson', 'i', 'miss', 'you', 'tooooo', 'onli', 'more', 'week', 'i', 'know', 'they', 'don', 't', 'but', 'it', 'still', 'made', 'me', 'miss', 'it']
# ['my', 'parent', 'are', 'drunk', 'fml', 'text', 'me', 'yeah']
# ['mapey', 'think', 'my', 'fave', 'f', 'driver', 'will', 'win', 'touch', 'wood', 'but', 'my', 'fave', 'team', 'is', 'pretti', 'much', 'out', 'of', 'it']
# ['morn', 'everyon', 'can', 't', 'believ', 'it', 's', 'the', 'last', 'day', 'of', 'my', 'holiday', 'back', 'to', 'the', 'grindston', 'tomorrow']
# ['perfect', 'spring', 'day', 'we', 'tri', 'to', 'go', 'to', 'emirgan', 'park', 'park', 'to', 'see', 'the', 'tulip', 'but', 'there', 'wasn', 't', 'ani', 'park', 'spent', 'three', 'hour', 'in', 'the', 'car']
# ['off', 'to', 'work', 'now', 'and', 'last', 'day', 'of', 'the', 'easter', 'holiday', 'so', 'back', 'to', 'colleg', 'aswel', 'tommorow']
# ['homework', 'still']
# ['tommcfli', 'i', 'wish', 'that', 'i', 'could', 'tweet', 'from', 'england']
# ['there', 'ha', 'to', 'be', 'more', 'to', 'life', 'than', 'thi']
# ['jenicahendrix', 'aw', 'kitti', 'that', 's', 'terribl']
# ['dwseventualwif', 'my', 'cousin', 'love', 'jon', 'and', 'he', 'hug', 'her', 'then', 'got', 'on', 'hi', 'phone', 'dure', 'the', 'm', 'amp', 'g', 'she', 'isnt', 'happi', 'either']
# ['my', 'mouth', 'hurt']
# ['sip', 'coffe', 'and', 'count', 'today', 'chore']
# ['low', 'doughnut', 'today', 'mah', 'so', 'not', 'in', 'the', 'mood', 'to', 'serv', 'sickli', 'doughnut', 'to', 'annoy', 'custom']
# ['eeeeek', 'back', 'to', 'school', 'on', 'tuesday']
# ['realli', 'am', 'realli', 'rune', 'factori', 'realli']
# ['mileycyru', 'i', 'have', 'school', 'tomorrow', 'again', 'booor', 'but', 'on', 'the', 'lesson', 'i', 'hum', 'on', 'breakout', 'we', 'gon', 'na', 'breakout', 'let', 'the', 'parti', 'start']
# ['mikewhitak', 'actual', 'honestli', 'that', 'would', 'be', 'creepi', 'if', 'someon', 'i', 'd', 'just', 'met', 'sent', 'me', 'that']
# ['wendi', 'uneduc', 'boater', 'scare', 'me', 'everi', 'time', 'i', 'take', 'passeng', 'for', 'a', 'cruis', 'i', 'don', 't', 'know', 'if', 'they', 'know', 'the', 'rule', 'of', 'the', 'road']
# ['tire', 'after', 'watch', 'f', 'excit', 'stuff', 'must', 'resist', 'fall', 'to', 'sleep', 'now', 'cup', 'of', 'tea', 'will', 'do', 'the', 'trick', 'nice']
# ['cant', 'sleep', 'help', 'me', 'clear', 'my', 'head', 'pleas', 'sigh']
# ['i', 'still', 'have', 'a', 'headach', 'it', 'been', 'a', 'week']
# ['did', 'someth', 'veri', 'veri', 'bad']
# ['sit', 'up', 'listen', 'to', 'music', 'till', 'am', 'caus', 'you', 're', 'upset', 'isn', 't', 'wise', 'boo', 'to', 'onli', 'hour', 'sleep']
# ['maliajona', 'hahaha', 'that', 'is', 'what', 'i', 'say', 'all', 'the', 'time', 'but', 'i', 'have', 'to', 'do', 'it']
# ['off', 'to', 'crystal', 'peak', 'with', 'mummi', 'bonsal', 'i', 'wan', 'na', 'go', 'to', 'the', 'next', 'waxon', 'in', 'newcastl']
# ['yeah', 'my', 'phone', 's', 'stuf']
# ['is', 'woder', 'whi', 'port', 'and', 'eagl', 'can', 'beat', 'the', 'top', 'team', 'thi', 'week', 'but', 'my', 'crow', 'can', 't']
# ['i', 'have', 'to', 'do', 'some', 'math']
# ['what', 'happen', 'with', 'am', 'org']
# ['o', 'ruthnin', 'usual', 'up', 'by', 'wish', 'i', 'could', 'lay', 'in', 'onc', 'in', 'a', 'while']
# ['doesn', 't', 'wamt', 'to', 'go', 'back', 'to', 'school', 'tomorrow']
# ['googl', 'reader', 'is', 'not', 'work', 'in', 'chrome', 'again', 'thi', 'morn']
# ['it', 's', 'am', 'and', 'i', 'm', 'awak', 'there', 'goest', 'sleep', 'routin', 'grrr', 'well', 'goodnight', 'amp', 'good', 'morn', 'ps', 'i', 'got', 'a', 'text', 'but', 'no', 'call', 'from', 'him']
# ['stephanya', 'what', 'wrong']
# ['is', 'bore', 'and', 'look', 'for', 'a', 'photo', 'to', 'upload', 'and', 'put', 'on', 'here', 'how', 'fun', 'is', 'that', 'not']
# ['listen', 'to', 'itun', 'in', 'song', 'are', 'gon', 'na', 'be', 'realli', 'annoy', 'song', 'frm', 'quot', 'greatest', 'guitar', 'song', 'quot', 'tht', 'my', 'bro', 'download']
# ['it', 's', 'far', 'too', 'nice', 'a', 'day', 'to', 'be', 'stuck', 'at', 'work']
# ['got', 'ta', 'go', 'to', 'the', 'doctor', 's', 'again']
# ['pigeon', 'of', 'reigat', 'yesterday', 'launch', 'sustain', 'shit', 'attack', 'on', 'car', 'just', 'had', 'to', 'clean', 'it', 'all', 'off']
# ['yesterday', 'i', 'attribut', 'my', 'sore', 'to', 'the', 'hr', 'walk', 'today', 'i', 'think', 'it', 'is', 'the', 'flu']
# ['allenhortaleza', 'food', 'tech', 'today']
# ['is', 'wish', 'that', 'he', 'could', 'go', 'to', 'offic', 'now', 'sigh', 'at', 'least', 'there', 'i', 'find', 'some', 'purpos', 'alon', 'and', 'miser']
# ['lucykd', 'ohh', 'honey', 'i', 'm', 'sorri', 'give', 'her', 'a', 'hug', 'from', 'me']
# ['absolutli', 'nufin', 'sum', 'coem', 'barnet']
# ['off', 'to', 'coventri']
# ['i', 'have', 'to', 'go', 'and', 'watch', 'manu', 'at', 'a', 'pub', 'but', 'i', 'wont', 'turn', 'off', 'asot']
# ['cat', 'just', 'had', 'a', 'bird', 'in', 'it', 'mouth', 'i', 'didnt', 'stand', 'for', 'it', 'though', 'i', 'think', 'i', 'save', 'it', 'broken', 'it', 'wing', 'and', 'leg', 'cat', 'are', 'evil', 'murder']
# ['want', 'to', 'see', 'britney', 'thi', 'summer', 'at', 'o', 'but', 'didnt', 'get', 'ticket', 'she', 'is', 'my', 'role', 'model']
# ['final', 'got', 'a', 'few', 'min', 'to', 'go', 'on', 'ps', 'and', 'have', 'to', 'wait', 'for', 'updat', 'for', 'it']
# ['lost', 'to', 'the', 'scum', 'depress', 'now']
# ['dammit', 'rl', 'suck', 'grand', 'egg']
# ['ugh', 'rafa', 'hasn', 't', 'drop', 'a', 'set', 'mont', 'carlo', 'sinc', 'the', 'final', 'in', 'amp', 'he', 'doe', 'it', 'day', 'against', 'djokov', 'ugh', 'again']
# ['awak', 'way', 'too', 'earli', 'i', 'liter', 'feel', 'nauseou', 'i', 'hate', 'thi', 'scienc', 'class']
# ['garcevisag', 'oh', 'so', 'you', 'make', 'me', 'feel', 'bad', 'befor', 'you', 'go']
# ['got', 'overrul', 'by', 'birthday', 'girl', 'go', 'to', 'ihop', 'realli', 'want', 'a', 'belgian', 'waffl', 'from', 'silver', 'diner']
# ['mysterygroup', 'ti', 'good', 'despit', 'have', 'to', 'go', 'to', 'work', 'when', 're', 'we', 'gon', 'na', 'find', 'out', 'who', 'y', 'all', 'are', 'lol']
# ['after', 'anoth', 'rough', 'start', 'rohan', 'and', 'i', 'made', 'it', 'through', 'the', 'night', 'okay', 'but', 'for', 'some', 'reason', 'he', 's', 'back', 'to', 'wake', 'up', 'at', 'am', 'waketrain']
# ['ha', 'to', 'work', 'then', 'studi']
# ['popher', 'lucki', 'it', 's', 'deff', 'a', 'sub', 'zero', 'temp', 'for', 'me', 'in', 'my', 'room']
# ['i', 'want', 'to', 'buy', 'a', 'load', 'of', 'hack', 'anim', 'but', 'amazon', 'don', 't', 'have', 'veri', 'mani', 'of', 'the', 'right', 'region', 'code']
# ['sineadskinn', 'poor', 'u', 'start', 'at', 'my', 'flat', 'went', 'to', 'a', 'cocktail', 'place', 'then', 'lock', 'tavern', 'then', 'went', 'to', 'our', 'friend', 'hous', 'to', 'listen', 'to', 'music']
# ['can', 't', 'realli', 'trust', 'weather', 'forecast', 'it', 's', 'sunni', 'but', 'we', 've', 'cancel', 'bear', 'mt', 'trip']
# ['is', 'work']
# ['thestapeliaco', 'glad', 'you', 'like', 'the', 'link', 'i', 'd', 'love', 'to', 'get', 'an', 'origin', 'of', 'one', 'like', 'that', 'but', 'none', 'are', 'avail']
# ['thomasrun', 'dude', 'did', 'not', 'get', 'thi', 'til', 'now', 'want', 'to', 'do', 'someth', 'so', 'bad', 'but', 'noth', 'pan', 'out', 'whi', 'you', 'no', 'call', 'me']
# ['with', 'one', 'sick', 'child', 'and', 'potenti', 'a', 'sick', 'wife', 'church', 'is', 'look', 'doubt', 'son', 'and', 'i', 'may', 'still', 'tri', 'and', 'make', 'it']
# ['ohhh', 'i', 'had', 'a', 'amaz', 'dream', 'holi', 'crap', 'it', 'seem', 'real', 'me', 'and', 'eminem', 'whi', 'did', 'i', 'have', 'to', 'wake', 'up']
# ['im', 'make', 'a', 'video', 'but', 'the', 'pereview', 'is', 'show', 'all', 'pixl', 'like']
# ['think', 'of', 'all', 'the', 'thing', 'i', 'could', 'be', 'do', 'better', 'than', 'work', 'right', 'now']
# ['dbostedor', 'nope']
# ['stephenpglenn', 'dalevich', 'thank', 'for', 'the', 'room', 'servic', 'suggest', 'but', 'unfortun', 'the', 'hotel', 'didn', 't', 'offer', 'that', 'servic', 'f']
# ['xxsimmyxx', 'no', 'kid', 'i', 'want', 'joe', 'back']
# ['doesnt', 'get', 'it']
# ['i', 'want', 'a', 'scrambl', 'egg', 'bagel', 'with', 'dill', 'cream', 'chees']
# ['got', 'her', 'stuff', 'from', 'the', 'laundri', 'shop', 'namansahan', 'lgi', 'akong', 'spongebob', 'yellow', 'shirt']
# ['i', 'wish', 'i', 'went', 'to', 'syracuseee', 'leav']
# ['trade', 'the', 'sun', 'run', 'with', 'walk', 'in', 'clinic', 'i', 'guess', 'twa', 'the', 'respons', 'choic']
# ['studi', 'sunday', 'lt', 'the', 'earth']
# ['can', 'not', 'believ', 'the', 'easter', 'holiday', 'are', 'over']
# ['is', 'go', 'to', 'watch', 'the', 'brewer', 'game', 'eat', 'soup', 'play', 'sim', 'and', 'sit', 'in', 'a', 'vapor', 'fill', 'room', 'stupid', 'cold', 'thi', 'suck']
# ['amalari', 'wish', 'i', 'could', 'be', 'there', 'sooner']
# ['iero', 'xxi', 'it', 'okay', 'l', 'oreal', 'are', 'shit', 'im', 'allerg', 'to', 'them', 'the', 'bastard', 'hahahaha']
# ['streetztalk', 'jaysonjphillip', 'i', 'wasn', 't', 'there', 'in', 'but', 'i', 'll', 'take', 'ur', 'word', 'y', 'all', 'need', 'get', 'in', 'that', 'stroll', 'competit', 'caus', 'it', 'wa']
# ['laura', 'awe', 'i', 'can', 't', 'see', 'them', 'either', 'well', 'i', 'can', 'demi', 'at', 'weme']
# ['well', 'i', 'guess', 'ill', 'just', 'hang', 'out', 'home', 'and', 'do', 'noth', 'blah']
# ['uh', 'oh', 'penalti', 'time', 'i', 'don', 't', 'like', 'it']
# ['good', 'morn', 'last', 'day', 'of', 'spring', 'break']
# ['is', 'tri', 'from', 'paint', 'the', 'loft', 'room']
# ['modernartrock', 'i', 'concur', 'dizzi', 'i', 'didn', 't', 'come', 'round', 'today', 'til', 'nearli', 'pm', 'that', 'realli', 'bad', 'earli', 'night', 'for', 'me', 'i', 'am', 'sure']
# ['look', 'out', 'my', 'window', 'it', 'rain', 'outsid']
# ['upload', 'myrtl', 'beach', 'pictur', 'miss', 'it']
# ['mussomitchel', 'aww', 'did', 'i', 'miss', 'the', 'contest']
# ['i', 'm', 'offici', 'in', 'a', 'bad', 'mood', 'i', 'don', 't', 'enjoy', 'it']
# ['wait', 'on', 'a', 'plane', 'with', 'engin', 'troubl']
# ['call', 'in', 'on', 'my', 'day', 'off', 'again']
# ['i', 'c', 'b', 't', 'h', 'gon', 'na', 'eat', 'brunch', 'soon', 'so', 'hungri', 'i', 'have', 'a', 'habit', 'of', 'not', 'eat', 'on', 'weekend', 'morn', 'xd']
# ['saskiawalk', 'poor', 'you', 'stinki', 'bbq', 'fume', 'are', 'no', 'fun']
# ['i', 'read', 'thi', 'beacus', 'i', 'want', 'back', 'my', 'ex', 'girlfrend']
# ['fashionrunn', 'me', 'me', 'i', 'did', 'mile', 'thi', 'morn', 'and', 'what', 's', 'new', 'the', 'wind', 'is', 'back', 'so', 'i', 'just', 'ran', 'a', 'bit', 'slower', 'today']
# ['eat', 'lunch', 'mmmm', 'when', 'life', 'throw', 'you', 'lemon', 'make', 'lemonad']
# ['woburn', 'for', 'a', 'few', 'day', 'day', 'til', 'graduat']
# ['intro', 'project', 'stuff', 'wahhh']
# ['lol', 'you', 'suck', 'okay', 'so', 'onli', 'thing', 'rn', 'is', 'hwk', 'dnw']
# ['relapsereact', 'man', 'i', 'm', 'still', 'so', 'sorri', 'about', 'that']
# ['have', 'the', 'headach', 'from', 'hell', 'noth', 'take', 'it', 'away', 'damn', 'hayfev']
# ['bioethic', 'went', 'well', 'but', 'now', 'i', 'm', 'alon', 'for', 'the', 'next', 'day']
# ['derekmarkham', 'seller', 'and', 'bragger', 'are', 'the', 'downfal', 'of', 'twitter']
# ['lhjunki', 'nowaz', 'how', 'old', 'are', 'you', 'i', 'feel', 'like', 'a', 'granni']
# ['whi', 'do', 'we', 'make', 'judgement', 'base', 'on', 'initi', 'appear', 'it', 'suck', 'when', 'u', 'r', 'on', 'the', 'receiv', 'end', 'pl', 'don', 't', 'do', 'thi', 'to', 'other']
# ['is', 'worri', 'thing', 'are', 'never', 'go', 'to', 'be', 'the', 'same', 'again']
# ['comput', 'overheatedd', 'i', 'think', 'i', 'smell', 'burn', 'laptop']
# ['still', 'w', 'headach', 'just', 'tweet', 'in', 'the', 'meantim', 'random', 'i', 'love', 'ezpass', 'brilliant', 'idea', 'can', 't', 'understand', 'whi', 'ppl', 'still', 'use', 'cash']
# ['mrsmop', 'ooh', 'think', 'if', 'you', 'tomorrow', 'it', 's', 'pure', 'tortur', 'isn', 't', 'it']
# ['no', 'more', 'long', 'hair', 'gon', 'na', 'miss', 'it']
# ['alberto', 'said', 'he', 'd', 'date', 'me', 'again', 'if', 'he', 'wa', 'singl', 'and', 'i', 'stupidli', 'agre', 'to', 'it']
# ['my', 'cold', 'bubbl', 'bath', 'to', 'eas', 'my', 'sunburn', 'help', 'a', 'ton', 'but', 'now', 'i', 'm', 'wide', 'awak']
# ['i', 'don', 't', 'want', 'to', 'go', 'to', 'work', 'tomorrow']
# ['it', 'way', 'too', 'earli', 'i', 'want', 'to', 'go', 'back', 'to', 'bed', 'i', 'realli', 'do', 'not', 'want', 'to', 'go', 'to', 'colleg', 'and', 'it', 'soo', 'unfair', 'my', 'brother', 'got', 'a', 'inset', 'day']
# ['sometim', 'life', 'just', 'seem', 'like', 'chapter', 'of', 'goodby']
# ['nooo', 'school', 'in', 'min', 'altough', 'i', 'm', 'still', 'in', 'bed']
# ['mrskutcher', 'how', 'about', 'mistreat', 'underpaid', 'unpaid', 'maid', 'helper', 'there', 'sure', 'is', 'a', 'lot', 'of', 'injustic', 'in', 'the', 'world', 'we', 'need', 'social', 'justic']
# ['stephenfri', 'crumb', 'whi', 'are', 'you', 'so', 'often', 'the', 'purveyor', 'of', 'mini', 'obit', 'what', 'a', 'shame']
# ['the', 'hard', 'water', 'in', 'thi', 'place', 'ha', 'complet', 'ruin', 'my', 'led', 'faucet', 'light']
# ['debat', 'how', 'to', 'do', 'quot', 'the', 'talk', 'quot', 'with', 'my', 'first', 'year', 'quot', 'siirrr', 'when', 'are', 'we', 'do', 'reproduct', 'quot']
# ['perezhilton', 'i', 'miss', 'you', 'by', 'a', 'week', 'everytim', 'you', 'are', 'in', 'vega']
# ['harisn', 'and', 'these', 'ha', 'been', 'not', 'a', 'singl', 'drop', 'of', 'rain', 'here', 'in', 'karachi', 'sinc', 'long']
# ['j', 'moneyi', 'haha', 'ikk', 'there', 'veri', 'busyyyy', 'but', 'it', 's', 'an', 'annoy', 'feelingg', 'lalala', 'at', 'atleast', 'i', 'get', 'to', 'talk', 'to', 'youu', 'd']
# ['khodg', 'laptop', 'just', 'lost', 'phone', 'and', 'have', 'to', 'get', 'a', 'new', 'one']
# ['cocoward', 'cant', 'believ', 'we', 'cant', 'watch', 'itt', 'lolssss']
# ['ahhh', 'fack', 'stupid', 'chocol', 'whi', 'did', 'i', 'have', 'to', 'eat', 'you', 'whyyyy']
# ['larrybloch', 'haha', 'oop', 'ignor', 'me', 'i', 'have', 'netlogist', 'and', 'netregistri', 'mix', 'up', 'bash', 'me', 'now', 'your', 'look', 'good']
# ['im', 'up', 'way', 'too', 'earli', 'on', 'my', 'last', 'day', 'off']
# ['exam', 'time', 'suck', 'tomorrow', 'exam', 'no', 'noth']
# ['perezhilton', 'the', 'comment', 'on', 'the', 'video', 'make', 'me', 'wan', 'na', 'hurl', 'it', 's', 'embarrass', 'that', 'so', 'mani', 'american', 'are', 'still', 'so', 'ignor']
# ['get', 'sick', 'again']
# ['too', 'hot', 'to', 'sleep', 'comfort']
# ['thankin', 'my', 'lucki', 'star', 'my', 'grammi', 'is', 'ok', 'w', 'her', 'fractur', 'rib', 'ugh']
# ['studiofairi', 'arghh', 'isi', 'help', 'me', 'out', 'i', 'cant', 'save', 'the', 'graphic', 'i', 'made', 'in', 'paint', 'shop', 'pro', 'i', 'mean', 'i', 'm', 'save', 'but', 'they', 're', 'not', 'show', 'on', 'folder']
# ['barbsbook', 'feel', 'slightli', 'depress', 'about', 'now']
# ['god', 'it', 'onli', 'feel', 'like', 'yesterday', 'i', 'wa', 'here', 'at', 'work', 'oh', 'yeah', 'i', 'wa']
# ['jessicaisfunni', 'you', 'fail', 'at', 'fun']
# ['what', 'happen', 'to', 'gmail', 'anyon', 'know', 'abt', 'it', 'can', 't', 'even', 'sign', 'in']
# ['i', 've', 'becom', 'a', 'twitter', 'monster', 'i', 'm', 'hardcor', 'addict', 'i', 'm', 'go', 'to', 'sleep', 'now', 'haha', 'school', 'tomorrow', 'ke', 'hueva']
# ['final', 'get', 'some', 'sleep', 'happi', 'birthday', 'hitler', 'and', 'happi', 'to', 'those', 'that', 'celebr', 'also', 'year', 'sinc', 'colombin', 'lot', 'today']
# ['sunday', 'funday', 'ha', 'come', 'to', 'an', 'end', 'ahhh', 'foooey', 'got', 'ta', 'sleep', 'now', 'amp', 'take', 'my', 'boy', 'to', 'the', 'airport', 'dumb', 'earli', 'the', 'thing', 'i', 'do', 'friend']
# ['oooooo', 'ok', 'cuz', 'i', 'wa', 'wonderin', 'how', 'the', 'hell', 'ur', 'about', 'to', 'eat', 'supper', 'when', 'it', 'like', 'cuz', 'i', 'thaugh', 'u', 'were', 'in', 'america', 'srri']
# ['i', 'have', 'hive', 'i', 'think']
# ['sharon', 'how', 'about', 'thi', 'pic', 'haha', 'im', 'swamp', 'at', 'work']
# ['anoth', 'monday', 'morn']
# ['is', 'back', 'in', 'univers', 'just', 'want', 'to', 'be', 'home', 'chill', 'in', 'the', 'sun', 'and', 'have', 'no', 'exam', 'to', 'worri', 'about']
# ['i', 'am', 'upset', 'bc', 'my', 'hubbi', 'will', 'be', 'gone', 'all', 'week', 'for', 'work']
# ['is', 'do', 'coursework', 'amp', 'need', 'help']
# ['sick', 'and', 'doe', 'not', 'wan', 'na', 'go', 'to', 'work']
# ['a', 'boozi', 'weekend', 'ha', 'been', 'had', 'but', 'now', 'the', 'inevit', 'return', 'to', 'realiti', 'newcastl', 'will', 'be', 'releg']
# ['tommcfli', 'i', 'would', 'if', 'i', 'live', 'in', 'england', 'but', 'i', 'live', 'in', 'au']
# ['knacker', 'even', 'though', 'molli', 'and', 'i', 'slept', 'until', 'she', 's', 'have', 'more', 'sleep', 'i', 'm', 'look', 'at', 'all', 'the', 'chore', 'never', 'end']
# ['miss', 'devon', 'hole', 'farm', 'amp', 'everyon', 'there', 'but', 'st', 'day', 'back', 'uni', 'had', 'a', 'great', 'workout', 'water', 'filter', 'bugger', 'clueless', 'about', 's', 'h', 'essay']
# ['back', 'here', 'again', 'roll', 'on', 'the', 'weekend', 'alreadi', 'lol']
# ['thinkin', 'waaaay', 'too', 'much', 'right', 'now']
# ['tri', 'to', 'studi', 'a', 'littl', 'bit', 'more', 'trigonometri', 'test', 'today']
# ['knunez', 'ouch']
# ['tara', 'rose', 'yeh', 'i', 've', 'notic', 'the', 'buzzen', 'is', 'down', 'i', 'woke', 'up', 'and', 'wa', 'told', 'that', 'the', 'buzzen', 'is', 'down', 'hope', 'it', 'won', 't', 'be', 'too', 'long', 'til', 'it', 's', 'up']
# ['i', 'found', 'my', 'pen', 'now', 'i', 'can', 'do', 'my', 'health', 'homework', 'thi', 'ad', 'is', 'soo', 'good', 'the', 'kid', 'are', 'move', 'their', 'eyebrow', 'to', 'the', 'music', 'o', 'it', 'cadburi']
# ['so', 'much', 'to', 'do', 'so', 'littl', 'time']
# ['now', 'look', 'at', 'a', 'pictur', 'of', 'a', 'appl', 'mac', 'i', 'want', 'one', 'noww']
# ['diet', 'start', 'today']
# ['boddington', 'yeah', 'i', 'know', 'i', 'll', 'be', 'feel', 'it', 'next', 'monday']
# ['wherearey', 'i', 'miss', 'you']
# ['i', 'hate', 'have', 'to', 'do', 'dissert', 'on', 'such', 'a', 'beauti', 'day']
# ['ugh', 'whi', 'doe', 'everyth', 'have', 'to', 'remind', 'me', 'of', 'quot', 'him', 'quot']
# ['almost', 'give', 'up', 'for', 'it', 'is', 'to', 'be', 'certain', 'that', 'noon', 'give', 'two', 'hoot', 'about', 'it', 'by', 'am', 'we', 'shall', 'see', 'partli', 'scare', 'still']
# ['we', 'need', 'help', 'to', 'prepar', 'ubuntu', 'releas', 'note', 'tour', 'and', 'upgrd', 'howto', 'in', 'persian', 'for', 'wiki', 'ubuntu', 'ir', 'but', 'no', 'one', 'care']
# ['wow', 'thi', 'holiday', 'break', 'for', 'me', 'is', 'soo', 'bore', 'i', 'end', 'up', 'watch', 'celebr', 'plastic', 'surgeri', 'on', 'channel', 'befor']
# ['is', 'skip', 'the', 'gym', 'to', 'finish', 'hi', 'damn', 'paper']
# ['is', 'super', 'tire', 'and', 'not', 'even', 'done', 'yet']
# ['drive', 'to', 'school', 'without', 'justin', 'text', 'me', 'what', 'a', 'lone', 'morn']
# ['bwilkin', 'hey', 'i', 'm', 'realli', 'sorri', 'to', 'hear', 'about', 'your', 'grandpa', 'that', 's', 'a', 'horribl', 'loss']
# ['break', 'out', 'the', 'first', 'skirt', 'of', 'the', 'season', 'would', 'have', 'worn', 'my', 'springi', 'white', 'pant', 'but', 'i', 'm', 'pretti', 'sure', 'they', 'no', 'longer', 'fit']
# ['i', 'wan', 'na', 'wake', 'up', 'feel', 'beauti', 'today', 'amp', 'tomorrow', 'amp', 'everyday', 'i', 'm', 'sick', 'of', 'feel', 'amp', 'look', 'like', 'shit']
# ['lazybearkhoa', 'it', 's', 'on', 'the', 'east', 'coast', 'and', 'i', 'm', 'at', 'school', 'that', 's', 'whi']
# ['had', 'a', 'great', 'birthday', 'parti', 'saturday', 'night', 'thank', 'to', 'everyon', 'who', 'help', 'me', 'celebr', 'my', 'pen', 'lost', 'yesterday', 'bring', 'on', 'game']
# ['morn', 'twittervers', 'get', 'myself', 'readi', 'for', 'a', 'long', 'and', 'raini', 'day', 'pretti', 'crappi', 'weather', 'out', 'there', 'compar', 'to', 'the', 'weekend']
# ['onward', 'to', 'hershey', 'lodg', 'for', 'the', 'psat', 'confer', 'if', 'i', 'can', 'find', 'it']
# ['mrjoehil', 'am', 'good', 'thank', 'joe', 'how', 'are', 'u', 'got', 'too', 'much', 'work', 'to', 'do', 'and', 'not', 'been', 'sleep', 'veri', 'well', 'tho', 'whi', 'do', 'u', 'finish', 'at']
# ['i', 'want', 'to', 'be', 'what', 'i', 'wa', 'when', 'i', 'want', 'to', 'be', 'what', 'i', 'am', 'now']
# ['mikefoong', 'too', 'bad', 'nambu', 'is', 'not', 'avail', 'for', 'ani', 'of', 'the', 'window', 'platform']
# ['want', 'to', 'revis', 'outsid', 'but', 'no', 'one', 'will', 'come', 'with', 'me']
# ['yawn', 'morn', 'it', 's', 'a', 'crappi', 'raini', 'day', 'outsid']
# ['think', 'work', 'hour', 'thi', 'week', 'might', 'just', 'kill', 'me', 'a', 'littl', 'bit', 'that', 'wat', 'you', 'get', 'for', 'have', 'a', 'week', 'off']
# ['i', 'kind', 'don', 't', 'like', 'my', 'hair', 'anymor']
# ['im', 'miss', 'a', 'gurl', 'name', 'quot', 'krishtalyn', 'quot', 'so', 'bad', 'for', 'now']
# ['monday', 'monday']
# ['great', 'morn', 'everyon', 'too', 'bad', 'it', 's', 'gloomi', 'when', 'i', 'm', 'not', 'in', 'the', 'offic', 'fb']
# ['poop', 'back', 'to', 'work']
# ['stuck', 'at', 'work', 'on', 'such', 'a', 'love', 'day']
# ['lpcouch', 'i', 'know', 'hahah', 'what', 'happen', 'to', 'the', 'site']
# ['birdonawir', 'hmmmm', 'i', 'don', 't', 'think', 'that', 's', 'alway', 'the', 'case', 'though', 'it', 'seem', 'that', 'i', 'can', 'onli', 'dm', 'those', 'that', 'show', 'up', 'in', 'that', 'lil', 'dm', 'list']
# ['methink', 'im', 'dead']
# ['my', 'day', 'off', 'awak', 'but', 'still', 'feel', 'ugh', 'i', 'couldn', 't', 'sleep', 'at', 'all', 'last', 'night']
# ['go', 'on', 'youtube', 'that', 'how', 'i', 'spend', 'most', 'of', 'my', 'day']
# ['relocatedyank', 'yeah', 'that', 'stink', 'mayb', 'they', 'll', 'get', 'it', 'on', 'the', 'pc', 'soon']
# ['amaz', 'weekend', 'kiss', 'my', 'life', 'goodby', 'for', 'the', 'next', 'two', 'week', 'though']
# ['syreeta', 'no', 'im', 'still', 'here', 'last', 'nite', 'wa', 'cool', 'i', 'miss', 'him', 'what', 'homegirl', 'say', 'ive', 'love', 'u', 'sinc', 'i', 'wa', 'the', 'shit', 'wont', 'go', 'away', 'lol']
# ['marquietta', 'late', 'there', 's', 'been', 'a', 'delay', 'of', 'up', 'to', 'an', 'hour', 'befor', 'they', 'show', 'up']
# ['hkar', 'aww', 'go', 'beat', 'em', 'up']
# ['just', 'listen', 'to', 'enter', 'shikari', 'new', 'song', 'they', 'made', 'me', 'cri', 'insid', 'i', 'wish', 'they', 'would', 'write', 'more', 'stuff', 'like', 'thi']
# ['hmez', 'inde', 'it', 'is', 'and', 'no', 'sunglass', 'to', 'wear', 'jvoooo']
# ['my', 'holiday', 'are', 'over', 'i', 'm', 'do', 'my', 'homework', 'now', 'you', 'guy', 'realli', 'don', 't', 'know', 'how', 'difficult', 'school', 'in', 'germani', 'is', 'it', 's', 'hard']
# ['i', 'm', 'a', 'teacher', 'again', 'bore', 'of', 'it', 'alreadi']
# ['it', 'go', 'to', 'be', 'hot']
# ['faf', 'dragon', 'yea', 'but', 'you', 'dont', 'have', 'to', 'drive', 'an', 'hour', 'to', 'work', 'anymor', 'either', 'sad', 'face']
# ['work', 'on', 'my', 'biochem', 'seminar', 'present']
# ['i', 'realli', 'would', 'like', 'to', 'download', 'tweeti', 'but', 'i', 'sadli', 'have', 'a', 'mac', 'run']
# ['whi', 'did', 'i', 'take', 'a', 'nape']
# ['simonelechat', 'aww', 'my', 'mummi', 'can', 't', 'watch', 'those', 'show', 'anim', 'are', 'too', 'special', 'whi', 'would', 'peopl', 'be', 'unkind', 'to', 'them']
# ['ddlovato', 'i', 'dunno', 'demi', 'ignor', 'them', 'they', 'are', 'dumb', 'they', 'onli', 'know', 'what', 'other', 'tell', 'them', 'to', 'be', 'true', 'than', 'to', 'actual', 'figur', 'it', 'out', 'urperfect']
# ['should', 'be', 'so', 'sleep', 'right', 'now', 'got', 'behind', 'schedul', 'a', 'lil', 'work', 'at', 'am']
# ['girlsgonechild', 'ye', 'finish', 'it', 'but', 'the', 'end', 'won', 't', 'be', 'as', 'good', 'as', 'the', 'rest', 'of', 'it', 'glad', 'i', 'read', 'it', 'nevertheless', 'proseho']
# ['punno', 'that', 's', 'what', 'they', 'tell', 'me', 'i', 'have', 'been', 'under', 'some', 'major', 'stress', 'late', 'so', 'mayb', 'and', 'no', 'thank', 'you', 'i', 'll', 'be', 'good', 'u', 'just', 'studi']
# ['no', 'green', 'day', 'tour', 'date', 'near', 'here', 'thi', 'will', 'be', 'fun', 'though']
# ['tokyo', 'sonata', 'want', 'to', 'say', 'someth', 'knew', 'what', 'it', 'want', 'to', 'say', 'someth', 'about', 'but', 'never', 'realli', 'said', 'it', 'deepli', 'disappoint']
# ['awak', 'real', 'shocker', 'there']
# ['not', 'feelin', 'good', 'ju', 'finish', 'watchin', 'for', 'the', 'love', 'of', 'ray', 'j', 'it', 'wa', 'veri', 'unexpect', 'hope', 'he', 'is', 'happi', 'tho']
# ['tri', 'fall', 'asleep', 'but', 'i', 'cant']
# ['singswel', 'yay', 'they', 'need', 'to', 'bring', 'him', 'back', 'as', 'a', 'regular', 'as', 'well', 'as', 'ali', 'larter', 'i', 'miss', 'them', 'they', 'should', 'resurrect', 'hi', 'mom', 'somehow', 'lol']
# ['on', 'the', 'way', 'to', 'school', 'miss', 'world', 'of', 'warcraft']
# ['djanonymousdc', 'keemi', 'come', 'bacckkkk']
# ['awal', 'but', 'if', 'i', 'go', 'shower', 'as', 'usual', 'i', 'll', 'probabl', 'get', 'in', 'someon', 's', 'way']
# ['i', 'hate', 'the', 'rain']
# ['drove', 'to', 'uni', 'and', 'got', 'my', 'assign', 'hand', 'in', 'just', 'in', 'time', 'phew', 'now', 'i', 'm', 'stuck', 'in', 'traffic']
# ['litamin', 'throw', 'away', 'my', 'shoe', 'amp', 'cloth', 'over', 'my', 'dead', 'bodi', 'ye', 'ye', 'let', 's', 'resum', 'e', 'shippuden', 'tour', 'but', 'e', 'lead', 'singer', 'not', 'arnd', 'leh']
# ...
# ['i', 'got', 'it', 'and', 'so', 'did', 'like', 'other', 'peopl', 'at', 'the', 'same', 'time', 'dana']
# ['i', 'm', 'in', 'the', 'gym', 'tear', 'it', 'down', 'fluffer', 'nutrer']
# ['batstat', 'dumbass', 'shame', 'though', 'no', 'worri', 'just', 'want', 'to', 'make', 'sure']
# ['busi', 'bee', 'today', 'get', 'my', 'tax', 'back', 'so', 'i', 'can', 'go', 'to', 'beniiiiiiii']
# ['great', 'mile', 'walk', 'thi', 'am', 'just', 'what', 'i', 'need', 'to', 'boost', 'my', 'energi', 'for', 'anoth', 'busi', 'product', 'day']
# ['manag', 'anoth', 'mile', 'riun', 'thi', 'morn', 'b', 'the', 'kid', 'got', 'up', 'for', 'school', 'gon', 'na', 'spend', 'the', 'rest', 'of', 'the', 'day', 'relax']
# ['to', 'mirai', 'earthacademi', 'you', 'were', 'name', 'aftr', 'my', 'tv']
# ['i', 'feel', 'load', 'better', 'right', 'now', 'manag', 'not', 'to', 'get', 'too', 'upset', 'thi', 'morn']
# ['turpentin', 'thanx', 'ye', 'we', 'have', 'build', 'up', 'a', 'great', 'life', 'togeth', 'with', 'respect', 'and', 'space', 'for', 'our', 'individu', 'need']
# ['miss', 'pipedream', 'if', 'mcfli', 'were', 'a', 'tv', 'show', 'flone', 'would', 'be', 'cannon']
# ['my', 'new', 'corpor', 'notebook', 'is', 'here']
# ['benjibrum', 'know', 'the', 'feel', 'good', 'job', 'you', 'can', 't', 'have', 'babi', 'that', 's', 'my', 'excus', 'realli', 'i', 'm', 'just', 'greedi']
# ['just', 'got', 'home', 'go', 'to', 'the', 'supermarket', 'with', 'si', 'soon']
# ['jorgeavilam', 'week', 'time', 'then', 'you', 'won', 't', 'have', 'to', 'enter', 'your', 'credenti', 'but', 'we', 'are', 'safe', 'to', 'use', 'cheer']
# ['adreamofhoney', 'i', 've', 'just', 'check', 'out', 'common', 'rider', 'good', 'call', 'i', 'might', 'have', 'to', 'purchas', 'some', 'cd', 'onc', 'my', 'pocket', 'are', 'line', 'with', 'penni']
# ['bundyb', 'jazzyjrw', 'here', 's', 'our', 'vodafon', 'info', 'on', 'the', 'htc', 'magic', 'gt']
# ['thevh', 'just', 'get', 'up', 'now', 'hurray', 'up', 'bounc', 'out', 'of', 'bed', 'women', 'and', 'take', 'the', 'day', 'head', 'on', 'now', 'up', 'and', 'at', 'um']
# ['just', 'got', 'to', 'work', 'lot', 'of', 'graphic', 'design', 'to', 'do', 'today', 'have', 'a', 'good', 'day', 'everyon']
# ['have', 'fun', 'around']
# ['read', 'quot', 'the', 'phenomenon', 'of', 'the', 'celeb', 'intern', 'quot', 'where', 'are', 'the', 'celeb', 'intern', 'at', 'nonprofit']
# ['geekgirldiva', 'kiss', 'for', 'me', 'whi', 'thank', 'you', 'grin']
# ['i', 'just', 'want', 'to', 'get', 'out', 'of', 'here', 'and', 'go', 'to', 'the', 'hospit', 'to', 'see', 'my', 'littl', 'nephew', 'who', 's', 'not', 'born', 'yet', 'but', 'almost']
# ['hi', 'there', 'anybodi', 'got', 'a', 'job', 'for', 'me', 'oil', 'amp', 'ga', 'logist', 'quot', 'aadvanspijk', 'yahoo', 'co', 'uk', 'quot']
# ['stephenfri', 'i', 'm', 'iranian', 'keep', 'it', 'up', 'pleas', 'p', 's', 'just', 'watch', 'old', 'ep', 'of', 'q', 'i', 'on', 'fraudster', 'don', 't', 'get', 'it', 'in', 'au', 'you', 'amp', 'gang', 'are', 'brill']
# ['so', 'world', 'histori', 'chemistri', 'english', 'he', 'i', 'come', 'lol']
# ['lizuk', 'lol', 'no', 'scone', 'but', 'definit', 'death', 'and', 'mayhem', 'and', 'magic']
# ['leathon', 'omg', 'realli', 'hahahaha', 'i', 'didn', 't', 'see', 'who', 'were', 'you', 'with']
# ['ketsangtai', 'thx', 'for', 'the', 'great', 'thoma', 'jefferson', 'quot', 'on', 'fb']
# ['derumi', 'oh', 'lol', 'well', 'it', 'wa', 'success']
# ['sukiebunni', 'yay', 'stay', 'warm']
# ['nobodi', 'know', 'whi', 'i', 'm', 'so', 'into', 'you', 'good', 'morn', 'i', 'm', 'so', 'sore', 'swam', 'ran', 'a', 'few', 'mile', 'and', 'hit', 'some', 'weight', 'the', 'last', 'two', 'day']
# ['a', 'new', 'day', 'ha', 'come']
# ['felicityful', 'am', 'equal', 'proud', 'of', 'my', 'other', 'ancestor', 'too', 'those', 'who', 'arriv', 'free', 'or', 'with', 'the', 'armi', 'one', 'of', 'my', 'convict', 'becam', 'a', 'policeman']
# ['is', 'at', 'work', 'yippe']
# ['danielcl', 'alexi', 's', 'first', 'album', 'quot', 'time', 'without', 'consequ', 'quot', 'wa', 'slightli', 'less', 'on', 'the', 'sad', 'side', 'but', 'i', 'prefer', 'thi']
# ['visitpa', 'excel', 'thank', 'you', 'veri', 'much', 'those', 'are', 'the', 'two', 'i', 'm', 'narrow', 'in', 'on']
# ['litoq', 'hey', 'man', 'did', 'u', 'see', 'that', 'davept', 'sub', 'hi', 'vanilla', 'ice', 'one', 'last', 'week']
# ['stambo', 'nz', 'bbbbhhhhahahahahahah', 'i', 'am', 'shouldn', 'you', 'be', 'sleep', 'mmm']
# ['it', 'so', 'hot', 'here', 'in', 'my', 'room', 'heheh', 'i', 'realli', 'wan', 'na', 'transfer', 'there', 'in', 'the', 'master', 's', 'bedroom', 'but', 'i', 'got', 'ta', 'prepar', 'for', 'tomorrow']
# ['eddiemalon', 'call', 'up', 'virgin', 'media', 'and', 'see', 'what', 'you', 'can', 'get', 'off', 'them', 'and', 'then', 'play', 'them', 'off', 'each', 'other', 'probabl', 'won', 't', 'work', 'either']
# ['go', 'to', 'work', 'not', 'so', 'fun', 'but', 'it', 's', 'moneyyyyy']
# ['oneloneknight', 'i', 'had', 'stew', 'i', 'skip', 'lunch', 'so', 'i', 'wa', 'total', 'hungri']
# ['paulpoteet', 'lora', 'from', 'indi', 'paul', 'you', 're', 'just', 'mean', 'i', 'don', 't', 'want', 'the', 'storm', 'until', 'tonit']
# ['join', 'the', 'lvatt', 'fun', 'i', 'so', 'got', 'ta', 'have', 'it', 'now', 'the', 'problem', 'is', 'it', 'isn', 't', 'out', 'yet', 'here', 'in', 'the', 'ph', 'boo', 'hoo']
# ['hi', 'dramatisgermani', 'well', 'deserv', 'olli', 'enjoy', 'the', 'show', 'amp', 'the', 'after', 'parti', 'too', 'my', 'friend', 'cheer']
# ['challyzatb', 'haha', 'i', 'suppos', 'not']
# ['reneejross', 'hey', 'there', 'rene']
# ['epiphon', 'me', 'but', 'it', 's', 'alreadi', 'pm', 'here']
# ['markleo', 'yay', 'at', 'least', 'she', 'is', 'support', 'the', 'ps', 'is', 'great', 'game', 'n', 'blu', 'ray', 'in', 'one', 'we', 'just', 'got', 'guitar', 'hero', 'sooo', 'addict']
# ['diamondhead', 'heheh', 'i', 'realli', 'enjoy', 'their', 'product', 'name', 'at', 'ikea', 'they', 'make', 'me', 'smile']
# ['monstersmonkey', 'would', 'love', 'to', 'see', 'the', 'pic']
# ['go', 'to', 'make', 'mango', 'panda']
# ['it', 'sunni', 'again', 'final']
# ['gavinelliott', 'dude', 'it', 's', 'leed', 'blatent', 'drive', 'and', 'i', 'll', 'have', 'to', 'drive', 'becaus', 'you', 'don', 't', 'have', 'a', 'car', 'lol']
# ['saudi', 'wow', 'you', 'realli', 'have', 'to', 'much', 'time', 'on', 'your', 'hand', 'to', 'twitter', 'youtub']
# ['ithalasakai', 'eu', 'posso', 'te', 'ensinar']
# ['i', 'could', 'here', 'angel', 'in', 'between', 'the', 'thunder', 'quot', 'clear', 'quot', 'then', 'boom', 'anoth', 'bolt', 'of', 'lighten', 'it', 'wa', 'awesom', 'to', 'watch', 'now', 'the', 'leav', 'are', 'out']
# ['tessmorri', 'pilgrimfamilyuk', 'wow', 'hun', 'that', 'fab', 'what', 'on']
# ['aplusk', 'oh', 'you', 'rock', 'ashton', 'i', 'love', 'you', 'forev', 'fan', 'mode', 'total', 'on']
# ['goodmorn']
# ['sheryl', 'stephen', 'bwahahahaha', 'could', 'be', 'i', 'heard', 'it', 'from', 'five', 'for', 'fight', 'though']
# ['had', 'min', 'to', 'get', 'to', 'my', 'connect', 'flight', 'desk', 'made', 'it']
# ['coredumpcr', 'bill', 'maher', 'amp', 'georg', 'carlin', 'god']
# ['georgezafiu', 'u', 'dont', 'know', 'but', 'i', 'wa', 'onc', 'a', 'littl', 'dolphin', 'just', 'like', 'you']
# ['am', 'watch', 'my', 'pm', 'chines', 'show']
# ['jasonfitch', 'that', 's', 'whi', 'i', 'put', 'the', 'smiley', 'face', 'there']
# ['lambgirl', 'lol', 'u', 'get', 'what', 'u', 'need', 'with', 'no', 'crowd']
# ['wtf', 'silvertsein', 'are', 'follwo', 'their', 'follwer', 'cool', 'i', 'like', 'them', 'more', 'and', 'more', 'x', 'd']
# ['searock', 'whi', 'thank', 'you', 'you', 're', 'veri', 'kind', 'but', 'there', 's', 'no', 'need', 'for', 'worri', 'it', 's', 'the', 'way', 'good', 'friend', 'mess', 'with', 'each', 'other', 'haha']
# ['romatim', 'it', 's', 'in', 'the', 'philippin']
# ['angiegriffin', 'good', 'morn', 'angi', 'i', 'll', 'be', 'in', 'the', 'atl', 'juli', 'th', 'th', 'what', 'happen', 'that', 'we', 'can', 'go', 'out', 'to']
# ['big', 'diel', 'thank', 'you', 'so', 'far', 'so', 'good', 'hope', 'you', 'have', 'a', 'good', 'day', 'too']
# ['i', 'just', 'found', 'out', 'one', 'of', 'my', 'favourit', 'on', 'here', 'bengeeb', 'is', 'actual', 'younger', 'than', 'me', 'whi', 'did', 'i', 'think', 'you', 'were', 'older', 'hun']
# ['new', 'to', 'twitter', 'and', 'readi', 'to', 'explor', 'what', 's', 'got', 'everyon', 'els', 'buzz', 'besid', 'that', 'i', 'm', 'chillin', 'listen', 'to', 'lenni', 'kravitz', 'xox', 'bless']
# ['read', 'the', 'black', 'swan', 'challeng', 'but', 'interest']
# ['oh', 'la', 'la', 'i', 'm', 'up', 'i', 'm', 'up', 'now', 'just', 'have', 'to', 'take', 'a', 'shower', 'and', 'get', 'readi', 'to', 'pick', 'sarah', 'up', 'yay', 'to', 'summer', 'in', 'accord', 'with', 'propheci']
# ['ambercadabra', 'pleas', 'forgiv', 'me', 'for', 'what', 'i', 'm', 'about', 'to', 'say', 'although', 'i', 'believ', 'you', 'll', 'understand', 'i', 'm', 'glad', 'to', 'hear', 'that', 'get', 'well', 'soon']
# ['go', 'check', 'my', 'first', 'song', 'sand', 'it']
# ['f', 'i', 've', 'heard', 'they', 'write', 'a', 'lot', 'of', 'java', 'at', 'squarespac', 'i', 'll', 'consid', 'ask', 'them']
# ['stewiehu', 'you', 'know', 'it', 'but', 'you', 'got', 'ta', 'do', 'thi', 'www', 'freethehood', 'com', 'lol']
# ['day', 'off', 'with', 'my', 'husband', 'to', 'celebr', 'our', 'nd', 'anniversari', 'off', 'to', 'the', 'golf', 'cours']
# ['to', 'afim', 'de', 'ir', 'no', 'show', 'da', 'shake']
# ['today', 'is', 'a', 'great', 'day', 'i', 'hope', 'you', 'are', 'all', 'have', 'one', 'too']
# ['emili', 'at', 'asylum', 'or', 'a', 'taser', 'i', 'won', 't', 'say', 'what', 'for', 'but', 'some', 'peopl', 'need', 'that', 'attitud', 'adjust']
# ['tlovvorn', 'yippeee', 'there', 's', 'noth', 'like', 'a', 'good', 'storm']
# ['on', 'wen', 'sday', 'iam', 'go', 'go', 'out', 'and', 'shop', 'for', 'makeup', 'and', 'next', 'week', 'ill', 'start', 'make', 'makeup', 'tutori']
# ['yme', 'hyvesredesign', 'tjaap', 'that', 'is']
# ['mayb', 'it', 'best', 'that', 'i', 'leav']
# ['buy', 'my', 'stuff', 'pleas', 'retweet']
# ['still', 'think', 'it', 's', 'awesom', 'that', 'dan', 'aykroid', 'call', 'me', 'yesterday', 'even', 'if', 'it', 'wa', 'just', 'an', 'autom', 'thing']
# ['sirc', 'howdi']
# ['problem', 'solv']
# ['clean', 'the', 'casa', 'then', 'get', 'readi', 'to', 'go', 'on', 'vaca', 'with', 'the', 'hubbi', 'i', 'can', 'say', 'that', 'now']
# ['pilki', 'ok', 'thank']
# ['just', 'unfollow', 'a', 'bunch', 'of', 'pple', 'who', 'never', 'updat', 'weren', 't', 'interest']
# ['ooh', 'we', 'get', 'to', 'see', 'princess', 'protect', 'programm', 'befor', 'america']
# ['woke', 'up', 'at', 'to', 'the', 'remedi', 'blast', 'toward', 'me', 'but', 'had', 'a', 'good', 'morn', 'jog']
# ['back', 'home', 'mommi', 'is', 'mad', 'dunno', 'whi', 'amp', 'i', 'don', 't', 'care', 'about', 'it', 'work', 'wa', 'great']
# ['tracecyru', 'r', 'you', 'gon', 'na', 'go', 'on', 'tour', 'with', 'miley', 'break', 'a', 'leg']
# ['happi', 'birthday', 'momma', 'go', 'shop']
# ['shawnstockman', 'i', 'm', 'watch', 'a', 'differ', 'world', 'and', 'i', 'love', 'that', 'part', 'quot', 'from', 'where', 'you', 'come', 'from', 'quot', 'i', 'can', 't', 'do', 'it', 'but', 'i', 'tri', 'everi', 'time']
# ['had', 'a', 'fantast', 'night', 'i', 'hope', 'i', 'get', 'to', 'see', 'him', 'again', 'today']
# ['is', 'back', 'to', 'be', 'a', 'sofa', 'junki', 'after', 'a', 'morn', 'of', 'applet', 'and', 'pretend', 'to', 'be', 'clever', 'fb']
# ['relax', 'for', 'a', 'free', 'movi', 'quot', 'the', 'uniti', 'of', 'spirit', 'and', 'matter', 'quot', 'pl', 'enjoy']
# ['alisondecad', 'you', 'onc', 'told', 'me', 'that', 'you', 'can', 'onli', 'be', 'two', 'colour', 'white', 'and', 'pink']
# ['recordj', 'ohh', 'rori', 'is', 'veri', 'special', 'even', 'if', 'i', 'think', 'i', 'did', 'scare', 'him', 'a', 'bit', 'x']
# ['punklibrarian', 'but', 'serious', 'congrat', 'to', 'you', 'and', 'lindsey']
# ['lucki', 'decis', 'but', 'i', 'll', 'take', 'the', 'tri', 'thank', 'you', 'lion']
# ['ohmygoff', 'check', 'that', 'out']
# ['listen', 'to', 'fli', 'with', 'me', 'lvatt']
# ['homeee', 'danc', 'subaru', 'wa', 'great']
# ['jonasbroth', 'omg', 'jb', 'of', 'cours', 'we', 'll', 'tell', 'everybodi', 'and', 'no', 'u', 're', 'the', 'best']
# ['at', 'starbuck', 'conduct', 'a', 'bunch', 'of', 'interview', 'got', 'my', 'car', 'back', 'thi', 'morn', 'a', 'bit', 'differ', 'than', 'a', 's']
# ['jonasbroth', 'you', 'were', 'amaaaaaaaz', 'in', 'wembley', 'yesterday', 'i', 'love', 'it', 'can', 't', 'wait', 'for', 'novemb', 'now']
# ['blondieann', 'wow', 'i', 've', 'never', 'own', 'china', 'never', 'saw', 'the', 'point', 'neat', 'heirloom', 'though', 'take', 'a', 'photo', 'some', 'time', 'if', 'it', 's', 'handi']
# ['mykal', 'hehe', 'ill', 'hold', 'it', 'and', 'drink', 'it', 'too', 'jaym', 'ajm', 'eric', 'chamber']
# ['ryanseacrest', 'listen', 'to', 'ya', 'onlin', 'right', 'now', 'all', 'the', 'way', 'from', 'spain']
# ['annnnnd', 'i', 'am', 'up']
# ['jeremygoni', 'haha', 'he', 'didn', 't', 'mean', 'to', 'he', 'kiss', 'it', 'to', 'make', 'it', 'feel', 'better', 'though', 'he', 's', 'so', 'cute']
# ['ashtonshay']
# ['eirashinoda', 'e', 'most', 'is', 'ade', 'tummi', 'lor', 'otherwis', 'u', 'dun', 'look', 'like', 'u', 've', 'increas', 'in', 'wt']
# ['therealnih', 'lol']
# ['italylogu', 'oh', 'ok', 'so', 'i', 'think', 'i', 'll', 'send', 'a', 'coupl', 'of', 'extra', 'mail', 'for', 'some', 'cool', 'place', 'i', 've', 'seen', 'i', 'll', 'let', 'u', 'know', 'how', 'it', 'goe']
# ['ye', 'thank']
# ['cali', 'chica', 'ooh', 'that', 'make', 'of', 'us', 'that', 's', 'happi', 'go', 'have', 'an', 'orchata', 'later', 'thi', 'afternoon', 'i', 'quot', 'l', 'have', 'u', 'if', 'u', 'have', 'a', 'quesidilla', 'me']
# ['how', 'mani', 'calori', 'do', 'i', 'burn', 'when', 'i', 'laugh', 'alot', 'i', 'hope']
# ['level', 'ceo', 'sound', 'like', 'a', 'wonder', 'time', 'you', 'got', 'plan', 'enjoy']
# ['quit', 'excit', 'about', 'my', 'gorgeou', 'meal', 'i', 'm', 'head', 'off', 'for', 'after', 'thi', 'in', 'london', 'more', 'absolut', 'random', 'to', 'add', 'to', 'my', 'day']
# ['at', 'london', 'standst', 'airport', 'right', 'now', 'not', 'long', 'now', 'until', 'i', 'get', 'home']
# ['redrant', 'those', 'complain', 'about', 'lack', 'of', 'energi', 'tend', 'to', 'wast', 'it', 'the', 'most']
# ['i', 'be', 'up', 'in', 'the', 'gym', 'just', 'workin', 'on', 'my', 'fit']
# ['just', 'for', 'me', 'not', 'onli', 'do', 'i', 'feel', 'special', 'now', 'the', 'whole', 'villag', 'hate', 'me', 'for', 'cut', 'of', 'their', 'phone', 'line', 'for', 'hour', 'oop']
# ['did', 'i', 'mention', 'i', 'got', 'my', 'teeth', 'clean', 'last', 'week', 'end', 'look', 'at', 'my', 'smile']
# ['becki', 'illson', 'so', 'did', 'tam', 'and', 'steve', 'thank', 'you', 'veri', 'much']
# ['got', 'my', 'credit', 'card', 'today']
# ['jonasbroth', 'ohmylord', 'the', 'new', 'album', 'is', 'amaz', 'thank', 'you', 'for', 'share', 'your', 'talent', 'with', 'us']
# ['ha', 'im', 'on', 'mr', 'z', 'good', 'side', 'so', 'he', 'love', 'meee', 'like', 'a', 'sister']
# ['catrambo', 'kitteh', 'alway', 'complain', 'it', 's', 'part', 'of', 'their', 'ador', 'program']
# ['phew', 'had', 'been', 'busi', 'today', 'at', 'last', 'got', 'a', 'bit', 'free', 'time', 'tri', 'to', 'improv', 'a', 'tini', 'shoe', 'app', 'it', 's', 'a', 'fun', 'time']
# ['it', 'turn', 'out', 'quit', 'nice']
# ['mizzshellz', 'goodmorn']
# ['jonasbrotherss', 'lt', 'im', 'sit', 'around', 'do', 'chore', 'amp', 'watch', 'tv']
# ['wake', 'up', 'to', 'tom', 'wait', 'sing', 'i', 'want', 'you', 'to', 'me']
# ['ride', 'around', 'in', 'a', 'limo', 'for', 'marlea', 'sweet', 'sixteen', 'yay', 'fun', 'stuff']
# ['raisecain', 'be', 'enamour']
# ['yourteub', 'bah', 'de', 'rien']
# ['elis', 'olivia', 'haha', 'all', 'the', 'nicknam', 'ppl', 'cal', 'me', 'heyi', 'in', 'nz', 'im', 'still', 'known', 'as', 'gosip', 'girl', 'the', 'drama', 'queen', 'n', 'the', 'dumbblond', 'im', 'of', 'a', 'kind']
# ['absolutspacegrl', 'do', 'all', 'danc', 'now']
# ['okay', 'so', 'the', 'plan', 'is', 'to', 'go', 'to', 'hot', 'topic', 'and', 'buy', 'all', 'the', 'harri', 'potter', 'stuff', 'i', 'can']
# ['get', 'readi', 'to', 'have', 'a', 'picnic', 'in', 'the', 'park', 'w', 'muh', 'partner', 'in', 'crime', 'and', 'besti', 'oh', 'press', 'ctrl', 't', 'and', 'then', 'ctrl', 'f', 'on', 'itun', 'for', 'a', 'surpris']

# %%
# stop words removal
tweets['text_processed']= tweets.apply(lambda row :remove_stopwords(row['text_processed']), axis = 1)

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# Get all the words from the column text_processed
without_sw = tweets.apply(lambda row :remove_stopwords(row['text_processed']), axis = 1)

# %%
# your code here

from sklearn.feature_extraction.text import CountVectorizer
bow_vect = CountVectorizer()

# # fit creates one entry for each different word seen  
# bow_vect.fit([" ".join(without_sw) #ignore the stopwords

# # #transform only considers the words that have been seen in fit -- This is an example text
# # bow_vect.transform([tweets['text_processed']]).toarray()

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
